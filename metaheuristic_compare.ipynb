# %% [markdown]
# 20 * 20 Instances

# %%
import matplotlib.pyplot as plt

# Data based on the table provided
instances_short = [
    "20_1", "20_2", "20_3", "20_4", "20_5", "20_6", "20_7", "20_8", "20_9", "20_10",
    "20_11", "20_12", "20_13", "20_14", "20_15", "20_16", "20_17", "20_18", "20_19", "20_20"
]

# Penalty values for SA-Local1, SA-Local2, and HABC-SA
sa_local1 = [6, 8, 8, 7, 9, 6, 13, 8, 5, 9, 10, 5, 6, 5, 6, 2, 6, 6, 5, 7]
sa_local2 = [0] * 20  # All zero penalties for SA-Local2
habc_sa = [0] * 20  # All zero penalties for HABC-SA

# Calculate the average penalty for SA-Local1
avg_sa_local1 = sum(sa_local1) / len(sa_local1)
avg_sa_local2 = sum(sa_local2) / len(sa_local2)
avg_habc_sa = sum(habc_sa) / len(habc_sa)

# Create the plot
plt.figure(figsize=(10, 6))

# Plot the lines
plt.plot(instances_short, sa_local1, marker='o', label="SA-Local1", color='blue')
plt.plot(instances_short, [i + 0.02 for i in sa_local2], marker='x', label="SA-Local2", color='green')
plt.plot(instances_short, habc_sa, marker='s', label="HABC-SA", color='red')

# Add a dashed line for the average
plt.axhline(y=avg_sa_local1, color='blue', linestyle='--', label=f'SA-Local1 Average ({avg_sa_local1:.2f})')
plt.axhline(y=avg_sa_local2, color='green', linestyle='--', label=f'SA-Local2 Average ({avg_sa_local2:.2f})')
plt.axhline(y=avg_habc_sa, color='red', linestyle='--', label=f'HABC-SA Average ({avg_habc_sa:.2f})')

# Adding labels and title
plt.xlabel('Instances')
plt.ylabel('Penalty')
plt.title('Penalty Comparison for SA-Local1, SA-Local2, and HABC-SA')
plt.xticks(rotation=90)
plt.legend()

# Display the plot
plt.tight_layout()
plt.show()

# %%
# Data from the new table provided
sa_local1_time = [16.53, 17.14, 16.89, 17.70, 16.62, 18.39, 17.25, 22.34, 22.57, 20.88, 
                  19.49, 17.90, 20.50, 17.54, 17.96, 20.62, 20.85, 18.86, 24.89, 17.42]
sa_local2_time = [0.44, 0.40, 0.48, 0.50, 0.49, 0.55, 0.43, 0.56, 0.52, 0.36, 
                  0.47, 0.42, 0.48, 0.40, 0.45, 0.47, 0.31, 0.33, 0.57, 0.32]
habc_sa_time = [7.26, 6.96, 6.03, 7.65, 5.91, 6.14, 5.47, 6.27, 3.45, 3.58, 
                3.30, 3.12, 5.77, 3.28, 3.40, 5.76, 5.93, 5.80, 3.36, 2.86]

# Calculate the average time for each
avg_sa_local1_time = sum(sa_local1_time) / len(sa_local1_time)
avg_sa_local2_time = sum(sa_local2_time) / len(sa_local2_time)
avg_habc_sa_time = sum(habc_sa_time) / len(habc_sa_time)

# Create the plot for the new data
plt.figure(figsize=(10, 6))

# Plot the lines
plt.plot(instances_short, sa_local1_time, marker='o', label="SA-Local1", color='blue')
plt.plot(instances_short, sa_local2_time, marker='x', label="SA-Local2", color='green')
plt.plot(instances_short, habc_sa_time, marker='s', label="HABC-SA", color='red')

# Add dashed lines for the averages
plt.axhline(y=avg_sa_local1_time, color='blue', linestyle='--', label=f'SA-Local1 Average ({avg_sa_local1_time:.2f})')
plt.axhline(y=avg_sa_local2_time, color='green', linestyle='--', label=f'SA-Local2 Average ({avg_sa_local2_time:.2f})')
plt.axhline(y=avg_habc_sa_time, color='red', linestyle='--', label=f'HABC-SA Average ({5.07:.2f})')

# Adding labels and title
plt.xlabel('Instances')
plt.ylabel('Running Time (seconds)')
plt.title('Running Time Comparison for SA-Local1, SA-Local2, and HABC-SA')
plt.xticks(rotation=90)
plt.legend()

# Display the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# 100 * 100 Instances

# %%
# New data from the latest table for penalties
sa_local1_penalty = [494, 586, 487, 568, 524, 586, 555, 545, 515, 647, 
                     564, 564, 606, 578, 568, 517, 647, 566, 549, 552]
sa_local2_penalty = [12, 2, 0, 2, 0, 0, 0, 0, 10, 0, 3, 1, 0, 0, 0, 1, 0, 7, 0, 0]
habc_sa_penalty = [0] * 20  # All zero penalties for HABC-SA

# Calculate the average penalties for each
avg_sa_local1_penalty = sum(sa_local1_penalty) / len(sa_local1_penalty)
avg_sa_local2_penalty = sum(sa_local2_penalty) / len(sa_local2_penalty)
avg_habc_sa_penalty = sum(habc_sa_penalty) / len(habc_sa_penalty)

# Update the instance labels to the desired format
instances_100 = [
    "100_1", "100_2", "100_3", "100_4", "100_5", "100_6", "100_7", "100_8", "100_9", "100_10",
    "100_11", "100_12", "100_13", "100_14", "100_15", "100_16", "100_17", "100_18", "100_19", "100_20"
]

# Create the plot for the penalty data
plt.figure(figsize=(10, 6))

# Plot the lines
plt.plot(instances_100, sa_local1_penalty, marker='o', label="SA-Local1", color='blue')
plt.plot(instances_100, sa_local2_penalty, marker='x', label="SA-Local2", color='green')
plt.plot(instances_100, habc_sa_penalty, marker='s', label="HABC-SA", color='red')

# Add dashed lines for the averages
plt.axhline(y=avg_sa_local1_penalty, color='blue', linestyle='--', label=f'SA-Local1 Average ({avg_sa_local1_penalty:.2f})')
plt.axhline(y=avg_sa_local2_penalty, color='green', linestyle='--', label=f'SA-Local2 Average ({avg_sa_local2_penalty:.2f})')
plt.axhline(y=avg_habc_sa_penalty, color='red', linestyle='--', label=f'HABC-SA Average ({avg_habc_sa_penalty:.2f})')

# Adding labels and title
plt.xlabel('Instances')
plt.ylabel('Penalty')
plt.title('Penalty Comparison for SA-Local1, SA-Local2, and HABC-SA')
plt.xticks(rotation=90)
plt.legend()

# Display the plot
plt.tight_layout()
plt.show()

# %%
# New data from the table provided for execution time
sa_local1_time_new = [322.83, 315.17, 397.37, 424.72, 376.58, 383.62, 410.73, 361.48, 289.38, 305.12,
                      302.56, 393.72, 328.23, 310.08, 323.21, 343.93, 344.43, 325.10, 354.95, 314.83]
sa_local2_time_new = [190.28, 220.01, 77.18, 165.16, 91.49, 73.88, 11.99, 82.53, 166.15, 56.54,
                      201.85, 218.14, 56.29, 44.10, 53.95, 170.82, 61.98, 246.79, 91.75, 71.78]
habc_sa_time_new = [835.79, 588.00, 526.61, 925.45, 529.94, 546.54, 655.86, 702.68, 816.52, 582.95,
                    1034.18, 1281.72, 388.70, 324.33, 327.82, 990.30, 475.14, 1602.35, 530.23, 422.94]

# Calculate the average time for each
avg_sa_local1_time_new = sum(sa_local1_time_new) / len(sa_local1_time_new)
avg_sa_local2_time_new = sum(sa_local2_time_new) / len(sa_local2_time_new)
avg_habc_sa_time_new = sum(habc_sa_time_new) / len(habc_sa_time_new)

# Create the plot for the new data (execution time)
plt.figure(figsize=(10, 6))

# Plot the lines
plt.plot(instances_100, sa_local1_time_new, marker='o', label="SA-Local1", color='blue')
plt.plot(instances_100, sa_local2_time_new, marker='x', label="SA-Local2", color='green')
plt.plot(instances_100, habc_sa_time_new, marker='s', label="HABC-SA", color='red')

# Add dashed lines for the averages
plt.axhline(y=avg_sa_local1_time_new, color='blue', linestyle='--', label=f'SA-Local1 Average ({avg_sa_local1_time_new:.2f})')
plt.axhline(y=avg_sa_local2_time_new, color='green', linestyle='--', label=f'SA-Local2 Average ({avg_sa_local2_time_new:.2f})')
plt.axhline(y=avg_habc_sa_time_new, color='red', linestyle='--', label=f'HABC-SA Average ({avg_habc_sa_time_new:.2f})')

# Adding labels and title
plt.xlabel('Instances')
plt.ylabel('Running Time (seconds)')
plt.title('Running Time Comparison for SA-Local1, SA-Local2, and HABC-SA')
plt.xticks(rotation=90)
plt.legend()

# Display the plot
plt.tight_layout()
plt.show()
